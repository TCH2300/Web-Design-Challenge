# %%
import pandas as pd

# %%
# File to Load (store file path)
file_path = "Resources/cities.csv"

# %%
# Read file and store to pandas df 
city_data_df = pd.read_csv(file_path)

# %%
result=city_data_df.to_html()

# %%
print(result)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City Number</th>
#       <th>City Name</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Windspeed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Nikolskoye</td>
#       <td>75</td>
#       <td>RU</td>
#       <td>1611994568</td>
#       <td>93</td>
#       <td>59.7035</td>
#       <td>30.7861</td>
#       <td>30.20</td>
#       <td>8.95</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Jamestown</td>
#       <td>90</td>
#       <td>US</td>
#       <td>1611994568</td>
#       <td>86</td>
#       <td>42.0970</td>
#       <td>-79.2353</td>
#       <td>19.00</td>
#       <td>6.91</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...
